# %% [markdown]
# # Numerical modelling of synaptic transmission in 3D

# %%
# %matplotlib notebook 
import numpy as np
import matplotlib.pyplot as plt
from getplate import getPlate
from getCylinder import GetCylinder

from matplotlib.animation import FuncAnimation
from IPython.display import HTML, clear_output

# %%
# %%html
# <style>
# .output_wrapper button.btn.btn-default, .output_wrapper .ui-dialog-titlebar {
#     display: none;
# } </style>
# Out:
# <style>
# .output_wrapper button.btn.btn-default, .output_wrapper .ui-dialog-titlebar {
#     display: none;
# } </style>

# %% [markdown]
# ## 3D
# * Build mass matrix and load vector
# * Need new mesh generator, new matrix and load vector builder, otherwise the same
# * Solve system of ODE's
# * More complicated animation

# %%
N = 100
n = 5
p, tri, edgeNodes = GetCylinder(N,n)

# %%
print(edgeNodes)
# Out:
# [[62 63]
#  [63 64]
#  [64 65]
#  [65 66]
#  [66 67]
#  [67 68]
#  [68 69]
#  [69 70]
#  [70 71]
#  [71 72]
#  [72 73]
#  [73 74]
#  [74 75]
#  [75 76]
#  [76 77]
#  [77 78]
#  [78 79]
#  [79 80]
#  [80 81]
#  [81 82]
#  [82 83]
#  [83 84]
#  [84 85]
#  [85 86]
#  [86 87]
#  [87 88]
#  [88 89]
#  [89 90]
#  [90 91]
#  [91 92]
#  [92 93]
#  [93 94]
#  [94 95]
#  [95 96]
#  [96 97]
#  [97 98]
#  [98 99]
#  [99 62]]

# %%
ax = plt.axes(projection='3d')

ax.scatter3D(p[:,0], p[:,1], p[:,2], c=p[:,2], cmap='Greens');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.unique(np.array([[0,0,1],[4,6,23],[5,3,4]]))
# Out:
# array([ 0,  1,  3,  4,  5,  6, 23])
